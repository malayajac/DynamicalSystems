# %% [markdown]
# #### Logistic Map Web Diagram

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def LogisticFn(mu, x):
    return mu * x * (1 - x)

# %%
x = np.linspace(0, 1, 1001)

# %%
mu = 2.8
f = LogisticFn(mu, x)
#-----
# Data points for cob web diagram:
N = 140  #Make this an even number.

CobWeb = [0.2]
for ii in range(N-1):
    CobWeb.append(LogisticFn(mu, CobWeb[ii]))

CobWeb_x = []
for n in range(int(N/2)):
    CobWeb_x.append(CobWeb[n])
    CobWeb_x.append(CobWeb[n])

CobWeb_y = [0]
for n in range(1, int(N/2)):
    CobWeb_y.append(CobWeb[n])
    CobWeb_y.append(CobWeb[n])
CobWeb_y.append(CobWeb[n+1])
#-----

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, f, "C0")
ax.plot(x, x, "C1")
ax.plot(CobWeb_x, CobWeb_y, 'r,-', alpha=0.7)
ax.plot(CobWeb_x[-20:], CobWeb_y[-20:], 'k.-')

ax.set_xlabel("$x_{n}$", fontsize=20)
ax.set_ylabel("$x_{n+1}$", fontsize=20)
ax.set_title("$\mu$={}".format(mu), fontsize=20)

ax.grid()
plt.show()

# %%
mu = 3.4
f = LogisticFn(mu, x)
#-----
# Data points for cob web diagram:
N = 140  #Make this an even number.

CobWeb = [0.2]
for ii in range(N-1):
    CobWeb.append(LogisticFn(mu, CobWeb[ii]))

CobWeb_x = []
for n in range(int(N/2)):
    CobWeb_x.append(CobWeb[n])
    CobWeb_x.append(CobWeb[n])

CobWeb_y = [0]
for n in range(1, int(N/2)):
    CobWeb_y.append(CobWeb[n])
    CobWeb_y.append(CobWeb[n])
CobWeb_y.append(CobWeb[n+1])
#-----

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, f, "C0")
ax.plot(x, x, "C1")
ax.plot(CobWeb_x, CobWeb_y, 'r,-', alpha=0.7)
ax.plot(CobWeb_x[-20:], CobWeb_y[-20:], 'k.-')

ax.set_xlabel("$x_{n}$", fontsize=20)
ax.set_ylabel("$x_{n+1}$", fontsize=20)
ax.set_title("$\mu$={}".format(mu), fontsize=20)

ax.grid()
plt.show()

# %%
mu = 3.56
f = LogisticFn(mu, x)
#-----
# Data points for cob web diagram:
N = 140  #Make this an even number.

CobWeb = [0.2]
for ii in range(N-1):
    CobWeb.append(LogisticFn(mu, CobWeb[ii]))

CobWeb_x = []
for n in range(int(N/2)):
    CobWeb_x.append(CobWeb[n])
    CobWeb_x.append(CobWeb[n])

CobWeb_y = [0]
for n in range(1, int(N/2)):
    CobWeb_y.append(CobWeb[n])
    CobWeb_y.append(CobWeb[n])
CobWeb_y.append(CobWeb[n+1])
#-----

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, f, "C0")
ax.plot(x, x, "C1")
ax.plot(CobWeb_x, CobWeb_y, 'r,-', alpha=0.7)
ax.plot(CobWeb_x[-20:], CobWeb_y[-20:], 'k.-')

ax.set_xlabel("$x_{n}$", fontsize=20)
ax.set_ylabel("$x_{n+1}$", fontsize=20)
ax.set_title("$\mu$={}".format(mu), fontsize=20)

ax.grid()
plt.show()

# %%
mu = 1 + np.sqrt(8) + 0.001
f = LogisticFn(mu, x)
#-----
# Data points for cob web diagram:
N = 140  #Make this an even number.

CobWeb = [0.2]
for ii in range(N-1):
    CobWeb.append(LogisticFn(mu, CobWeb[ii]))

CobWeb_x = []
for n in range(int(N/2)):
    CobWeb_x.append(CobWeb[n])
    CobWeb_x.append(CobWeb[n])

CobWeb_y = [0]
for n in range(1, int(N/2)):
    CobWeb_y.append(CobWeb[n])
    CobWeb_y.append(CobWeb[n])
CobWeb_y.append(CobWeb[n+1])
#-----

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, f, "C0")
ax.plot(x, x, "C1")
ax.plot(CobWeb_x, CobWeb_y, 'r,-', alpha=0.7)
ax.plot(CobWeb_x[-20:], CobWeb_y[-20:], 'k.-')

ax.set_xlabel("$x_{n}$", fontsize=20)
ax.set_ylabel("$x_{n+1}$", fontsize=20)
ax.set_title("$\mu$={}".format(mu), fontsize=20)

ax.grid()
plt.show()

# %%
mu = 4
f = LogisticFn(mu, x)
#-----
# Data points for cob web diagram:
N = 140  #Make this an even number.

CobWeb = [0.2]
for ii in range(N-1):
    CobWeb.append(LogisticFn(mu, CobWeb[ii]))

CobWeb_x = []
for n in range(int(N/2)):
    CobWeb_x.append(CobWeb[n])
    CobWeb_x.append(CobWeb[n])

CobWeb_y = [0]
for n in range(1, int(N/2)):
    CobWeb_y.append(CobWeb[n])
    CobWeb_y.append(CobWeb[n])
CobWeb_y.append(CobWeb[n+1])
#-----

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, f, "C0")
ax.plot(x, x, "C1")
ax.plot(CobWeb_x, CobWeb_y, 'r,-', alpha=0.7)
# ax.plot(CobWeb_x[-20:], CobWeb_y[-20:], 'k.-')

ax.set_xlabel("$x_{n}$", fontsize=20)
ax.set_ylabel("$x_{n+1}$", fontsize=20)
ax.set_title("$\mu$={}".format(mu), fontsize=20)

ax.grid()
plt.show()

# %% [markdown]
# #### Interactive Web Diagram
